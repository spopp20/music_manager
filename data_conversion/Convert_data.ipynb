# %% [markdown]
# ## Data Conversion
#
# The original source music_v3 relational database is in a MySql database. The destination database is a Mongo Database.
#
# Source data field clean-up methods are in the cell below

# %%
import numpy as np
import pandas as pd
import re


def title_cleanup(title):
    """
    Process song titles and return
    cleaned collection (tag), title and notes
    """
    # title beginning characters
    r1 = re.findall(r'^[xX]', title)
    r2 = re.findall(r'^[qQ]', title)
    tag = None
    note = None
    
    # Special Character to represent collection tags
    if r1:
        tag = 'Youth'
        title = re.sub(r'^[xX]', '', title)
    elif r2:
        tag = 'Special'
        title = re.sub(r'^[qQ]', '', title)
    else:
        tag = 'Main'
    
    title = title.strip()
    
    # remove the extra dash seperating special character
    if title.startswith('-'):
        title = title[1 : : ]
        title = title.strip()
    
    # Read notes inside parenthesis and slice off first occurance
    found = re.findall(r'\((.*?) *\)', title)
    if found:
        note = found[0]
        title = title.rpartition('(')[0].strip()
    
    return title, tag, note

def begin_words_cleanup(words):
    """
    Provide the first 4 cleaned words in English and possibly =S(panish
    df - a dataframe with song lyrics
    """
    spanish = None
    english = words.split(' ')[:12] # first 12 words
    english = ' '.join(english)
    english = english.replace('\r', '')
    english = english.replace('\n', ' ')
    # Within parens
    found = re.findall(r'\((.*?) *\)', english)
    
    if found:
        spanish = found[0]
        spanish = ' '.join(spanish.split()[:4])
        # replace parens and content
        english = re.sub(r' ?\([^)]+\)', '', english)
    
    # Limit to 4 words maximum
    english = ' '.join(english.split()[:4])
        
    return english, spanish

def process_songs(df):
    """
    Process rows in the songs dataframe to clean-up and recover data
    df - The source Dataframe
    return the cleaned Dataframe
    """
    for (idx, row) in df.iterrows():
        row_id = row['id']
        title, tag, note = title_cleanup(row.get('title'))
        
        # Change in the actual dataframe.
        df.loc[idx, 'tag'] = tag
        df.loc[idx, 'title'] = title
        df.loc[idx, 'note'] = note

        english, spanish = begin_words_cleanup(row.get('words'))
        df.loc[idx, 'begin_english'] = english
        df.loc[idx, 'begin_spanish'] = spanish
         
    return df

def flatten_list_of_list(lol):
    """Flatten a list of Lists"""
    result = [r for sublist in lol for r in sublist]
    return result
    
def do_language_cleanup(words):
    """
    Seperate mixed, english, and spanish words and return all three.
    """
    english = words
    spanish = None
    
    # Spanish Within parens
    found = re.findall(r'\((.*?) *\)', words)
    
    if found:
        print(found)
        spanish = ' '.join(found)
        # replace parens and content
        english = re.sub(r' ?\([^)]+\)', '', words)
    return words, english, spanish
    
def process_scores_voice(df):
    """
    Process rows in the scores voice dataframe to clean-up and recover data
    df - The source Dataframe
    return the cleaned Dataframe
    """
    for (idx, row) in df.iterrows():
        row_id = row['id']
        
        mixed, english, spanish = do_language_cleanup(row.get('words'))
        df.loc[idx, 'words'] = mixed
        df.loc[idx, 'english'] = english
        df.loc[idx, 'spanish'] = spanish
        
        #  TODO process instrument score images
        
    return df

def cleanup_songs(df):
    """
    Do the full songs source data clean-up
    df - a dataframe with the source songs.
    """
    df = process_songs(df)
    df.drop(columns=['words'], inplace=True)
    print(df.head())
    return df

def cleanup_scores(dfvoice, dfinstrument=None):
    """
    Do the scores source data for the vocal instrument clean-up
    df - a dataframe with the source vocal scores
    """
    df = process_scores_voice(dfvoice)
    print(df.head())
    return df

# %%
# Test do_language_cleanup
r0 = do_language_cleanup('Blessing and Honor (Bendición y honor) \r\nGlory and Power (gloria y poder)')
r0
# Out:
# ['Bendición y honor', 'gloria y poder']
# ('Blessing and Honor (Bendición y honor) \r\nGlory and Power (gloria y poder)',
#  'Blessing and Honor \r\nGlory and Power',
#  'Bendición y honor gloria y poder')

# %%
# A test of the title cleanup function
r1 = title_cleanup('Q-MyTitle belongs (my note)')
r1
# Out:
# ('MyTitle belongs', 'Special', 'my note')

# %%
# A test of the words cleanup method
r2 = begin_words_cleanup('Blessing and Honor (Bendición y honor) Glory and Power (gloria y poder)')
r2
# Out:
# ('Blessing and Honor Glory', 'Bendición y honor')

# %% [markdown]
# ## Query legacy music database
#
# Query for the source music data and then perform the cleanup needed in the methods above

# %%
import openpyxl
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
import pymysql
from dotenv import dotenv_values

# Read secret values
config = dotenv_values('.env')
SQLALCHEMY_DATABASE_URI = config.get('SQLALCHEMY_DATABASE_URI')
engine = create_engine(SQLALCHEMY_DATABASE_URI, echo=False)


SONGS_SQL = text(
"""
SELECT
  id, 
  tempo_cd_id,
  arrangement,
  NULL as tag,
  title,
  start_key, 
  aux_key,
  words,
  NULL as begin_english,
  NULL as begin_spanish,
  NULL as note
FROM song;
""")

SCORES_SQL = text(
"""
SELECT
  id,
  id as song, 
  8 as instrument,
  words,
  NULL as english,
  NULL as spanish,
  'text/plain' as mime_type
from song;
""")

with engine.connect() as conn:
    songs = pd.read_sql(SONGS_SQL, conn)
    #print(songs.head())
    
    scores = pd.read_sql(SCORES_SQL, conn)
    #print(scores.head())
    


songs = cleanup_songs(songs)
scores = cleanup_scores(scores)


songs.to_excel('songs.xlsx', index=False)
scores.to_excel('scores.xlsx', index=False)
# Out:
#    id  tempo_cd_id                     arrangement   tag  \
# 0   1            1  Faithful one, so unchanging...  Main
# 1   2            4                            None  Main
# 2   3            3     Jesus is my Lord and Savior  Main
# 3   5            2                            None  Main
# 4   7            4                            None  Main
#
#                          title start_key aux_key               begin_english  \
# 0                  Ageless One         C    None  Faithful One So unchanging
# 1  Ah Lord God /In Him We Live         C    None           Ah, Lord God Thou
# 2     You're Alive Forevermore        Dm    None            Jesus is my Lord
# 3         All Honor, All Glory        Dm    None       All honor, All glory,
# 4       All The Way To Calvary      Eb/F    None              All the way to
#
#        begin_spanish  note
# 0               None  None
# 1  !Oh Señor Jehová!  None
# 2               None  None
# 3               None  None
# 4  Todo el camino al  None
# ['!Oh Señor Jehová!', 'He aquí que tú hiciste el cielo', 'y la tierra', 'Con tu gran poder', '!Oh Señor Jehová!', 'He aquí que tú hiciste el cielo', 'y la tierra', 'Con tu brazo extendido', 'Ni hay nada que sea difícil para ti', 'Hay nada que sea difícil para ti', 'Dios grande, poderoso', 'Grande en consejo', 'Magnífico en hechos', 'Magnífico en hechos', 'Nada, nada', 'Absolutamente nada', 'Nada es demasiado difícil para ti', 'Porque en él vivimos', 'Y nos movemos, y somos', 'Porque en él vivimos', 'Y nos movemos, y somos', 'Haz un ruido alegre', 'Cantad a Dios', 'Cuéntale de tu amor', 'Baila ante Él', 'Haz un ruido alegre', 'Cantad a Dios', 'Cuéntale de tu amor', 'Aleluya!']
# ['Todo el camino al Calvario', 'Él fue por mí', 'Él fue por mí', 'Él fue por mí', 'Todo el camino al Calvario', 'Él fue por mí', 'Él murió para liberarme.', 'Aunque tuve', 'Tantos, muchos pecados,', 'Jesús se los llevó a todos', 'Y Él me perdonó.', 'Aunque tuve', 'Tantos, muchos pecados,', 'Jesús se los llevó a todos', 'Y Él me perdonó.']
# ['Bendición y honor', 'gloria y poder', 'Sean para El Anciano de los Días', 'De todas las naciónes', 'toda la creación', 'Se inclina ante el Anciano de los Días', 'Cada lengua en el cielo y la tierra', 'Declarara tu gloria', 'Todas las rodillas se doblaran ante tu trono', 'en adoracion', 'Tu seras exaltado, O dios', 'Y tu reino', 'no pasará Anciano de los dias', 'tu reino reinara', 'sobre toda la tierra', 'Canta al Anciano de los Dias', 'porque ninguno puede compararse', 'a tu valor incomparable', 'canta al Anciano de los Dias', 'Cada lengua en el cielo y en la tierra', 'Declarará tu gloria', 'Todas las rodillas se doblaran ante tu trono', 'En Adoracion', 'seras exaltado, O Dios', 'Y tu reino', 'no pasara Anciano de los Días', 'Anciano de los Días', 'Anciano de los Días']
# ['levantate, brilla', 'porque tu luz ha venido', 'levantate, brilla', 'porque tu luz ha venido', 'y la gloria de Jehova ha resucitado', 'la gloria de Jehova a venido', 'la gloria de Senor', 'ha resucitado sobre ti']
# ['A tu diestra', 'A tu diestra', 'Hay delicias para siempre', 'A tu diestra', 'A tu diestra', 'Hay delicias para siempre', 'Hay plenitud de gozo', 'Plenitud de gozo', 'En tu presencia', 'Hay plenitud de gozo', 'A tu diestra', 'A tu diestra', 'Hay delicias para siempre', 'Los que confían en Jehová', 'Son como el monte de Sion', 'Que no se mueve', 'Sino que permanece para siempre', 'Como Jerusalén tiene', 'Montes alrededor de ella', 'Así Jehová está alrededor', 'De su pueblo', 'Así Jehová está alrededor', 'De su pueblo', 'Desde ahora y para siempre']
# ['Te glorificamos, te glorificamos', 'Te glorificamos, te glorificamos', 'Te glorificamos en los cielos;', 'Te glorificamos en la tierra', 'Te glorificamos en este templo', 'Jesús, Jesús,', 'Te glorificamos', 'Jesús, Jesús,', 'Te glorificamos', 'Adora al Señor, adora al Señor.', 'Adora al Señor, adora al Señor', 'Adora al Señor en los cielos', 'Adora al Señor en la tierra', 'Adora al Señor en este templo', 'Jesús, Jesús,', 'Te glorificamos', 'Jesús, Jesús,', 'Te glorificamos']
# ['Ten misericordia de mí, oh Dios', 'Porque en ti ha confiado mi alma', 'Ten misericordia de mí, oh Dios', 'Porque en ti ha confiado mi alma', 'Y en la sombra de tus alas', 'Voy a amparar', 'Y en la sombra de tus alas', 'Voy a quedar', 'Hasta que pasen las tormentas', 'Mi corazon esta fijo', 'Mi corazón está fijo, mi Dios', 'Cantaré, y te alabare', 'Mi corazon esta fijo', 'Mi corazón está fijo, oh Dios', 'Porque me has enviado tu verdad']
# ['Sé tú exaltado', 'Oh Dios, oh Señor', 'Sé tú exaltado', 'Oh Dios, oh Señor', 'Exalta al Señor, nuestro Dios', 'Y adorar en su santo monte', 'Porque el Señor', 'Dios es santo', 'Porque el Señor', 'Dios es santo', 'Sé tú exaltado, Señor', 'En nuestros corazones', 'Porque somos tuyos y', 'Solo tuyos', 'Sé tú exaltado, Señor', 'En nuestros corazones']
# ['Mirad', 'cuán bueno y cuán delicioso', 'es habitar los hermanos juntos en armonía', 'Mirad', 'cuán bueno y cuán delicioso', 'es habitar los hermanos juntos en armonía', 'Es como el buen óleo', 'Sobre la cabeza', 'El cual desciende sobre la barba', 'La barba de Aarón', 'Mirad', 'cuán bueno y cuán delicioso', 'es habitar los hermanos juntos en armonía', 'Como el rocío de Hermón', 'Como el rocío', 'Que desciende sobre', 'Los montes de Sion', 'Porque allí', 'Envía Jehová', 'Bendición Y vida eterna']
# ['Bendice al Señor', 'Todos los sirvientes del Señor.', 'Levanta tus manos', 'En el santuario', 'Y bendiga, bendiga al Senor.', 'Aleluya, Aleluya!', 'Eres Señor', 'Eres Señor', 'Aleluya, Jesus es el Señor', 'Aleluya, Jesus es el Señor', 'Aleluya, Aleluya!', 'El es Rey. El es Rey', 'Aleluya, Jesus es Rey', 'Aleluya, Jesus es el Rey']
# ['Bienaventurados los', 'Que habitan en tu casa', 'Perpetuamente te alabarán.', 'Bienaventurados los', 'Que habitan en tu casa', 'Perpetuamente te alabarán.', 'Bienaventurado el hombre', 'que tiene en ti sus fuerzas', 'En cuyo corazón', 'Están los caminos de ellos.', 'Bienaventurado el hombre', 'que tiene en ti sus fuerzas', 'En cuyo corazón', 'Están los caminos de ellos.', 'Porque el Senor, Dios', 'es un sol y un escudo', 'El Senor te dara', 'Gracia y gloria.', 'Nada bueno', 'El retengara', 'De ellos que caminan rectamente.', 'Jehová de los ejércitos,', 'Dichoso el hombre que confia en ti.', 'Que confia en ti.', 'Jehová de los ejércitos,', 'Dichoso el hombre que confia en ti.', 'Que confia en ti.', 'Que confia en ti', 'Atravesando', 'El valle de lágrimas', 'El hace un pozo,', 'El hace un pozo.', 'La lluvia temprana', 'cubre con bendicion', 'El hace un pozo,', 'El hace un pozo.', 'Van de fuerza', 'en fuerza a Sion;', 'todos ellos', 'aparecen ante nuestro Dios.', 'Van de fuerza', 'en fuerza a Sion;', 'todos ellos', 'aparecen ante nuestro Dios.']
# ['Bendito sea el Señor', 'que reina para siempre', 'Reina para siempre', 'Bendito sea el Señor', 'que reina para siempre', 'Levantaré mi voz en alabanzas', 'Levantaré mi voz en la canción', 'Lo levantaré por su misericordia', 'Alabadlo, Alabadlo!', 'Aleluya', 'Dios es digno', 'Aleuya', 'Bendito sea su nombre', 'Aleluya', 'Dios es digno', 'Levanta tus manos', 'Aplaude', 'Alabadlo, Alabadlo!', 'Alabadlo! Bendito sea su nombre santo', 'Alabadlo, Alabadlo!', 'Bendito sea el Señor', 'que reina para siempre', 'Reina para siempre', 'Bendito sea el Señor', 'que reina para siempre', 'Bendito sea el Señor!']
# ['Sopla la trompeta, sopla', 'dejaremos que todo este mundo sepa', 'Que Jesús regresará de nuevo', 'Quizas por la mañana o mediodía', 'Sé que vendrá pronto', 'Lo encontraré arriba en el aire', 'Quizas por la mañana o mediodía', 'Sé que vendrá pronto', 'A llevarme a la', 'Mansión que ha preparado', 'Sopla la trompeta, sopla', 'dejaremos que todo este mundo sepa', 'que Jesus regresara de nuevo', 'Mira alrededor', 'Hay problemas en todas las manos', 'No puedes sentirlo en el aire?', 'No hay necesidad de preocuparse', 'si mi Jesus has conocido', 'Porque Jesus regresara de nuevo', 'Sopla la trompeta, sopla', 'dejaremos que todo el mundo sepa', 'que Jesus regresara de nuevo', 'Miren, trabajen y oren', 'porque El puede regresar hoy', 'lo encontrare, arriba en el aire', 'Miren, trabajen y oren', 'porque El puede regresar hoy', 'a este mundo viejo', 'con mucho gusto, me despedire']
# ['Él es el Salvador, Redentor,', 'Nuestro cordero sacrificado', 'Creador de todo', 'Jehová, YO SOY,', 'Consejero Maravilloso,', 'Digno de alabanza', 'poderoso y asombroso', '¡Anciano de días!', 'Ven, adoremos al Señor,', 'Todos que lo conocen por Nombre.', 'Ven, adoremos al Señor,', 'Jesus, por siempre el mismo.', 'Vamos a levantar nuestra voz', 'para cantar y regocijarse.', 'Ven, adoremos al Señor.', 'Él es la dulce Rosa de Sharon', 'La Brillante Estrella de la Mañana', 'Digno de gloria y honor y poder.', 'Mesías, el Santo,', 'Maestro y Rey', 'Toda la creación', '¡Se levantará y cantará!', 'Ven, adoremos al Señor,', 'Todos que lo conocen por Nombre.', 'Ven, adoremos al Señor,', 'Jesus, por siempre el mismo.', 'Vamos a levantar nuestra voz', 'para cantar y regocijarse.', 'Ven, adoremos al Señor.', 'Él es el Alfa, Omega,', 'El Primero y el último.', 'Él quita de su gente', 'los pecados del pasado', 'Deje todas las manos que', 'Han caído se levanten.', 'Con alegría y baile,', 'sea alabado Jesús!', 'Ven, adoremos al Señor,', 'Todos que lo conocen por Nombre.', 'Ven, adoremos al Señor,', 'Jesus,por siempre el mismo.', 'Vamos a levantar nuestra voz', 'para cantar y regocijarse.', 'Ven, adoremos al Señor.']
# ['como en los días de Elias', 'Declarando la Palabra', 'De Dios', 'Y como en días también de', 'Moisés tu servio', 'siendo restaurada la Justicia', 'Y aunque estos son dias', 'de gran batallas', 'de hambre, de oscuridad', 'Y espada', 'Aún nosotros somos la voz', 'en el desierto clamando,', '"Prepara el camino al Señor"', 'he aquí que viene', 'montado en las nubes', 'Brillando como el sol', 'Al sonido de la trumpeta', 'levanta tu voz', 'es el año de Jubileo', 'Desde El Monte Sion', 'La salvación viene', 'y como el los días de Ezequiel', 'Los huesos secos se vuelven como carne', 'Y como en días también de', 'David tu siervo', 'construyendo un templo de alabanza', 'y estos son días', 'de la Cosecha', 'Los campos son tan blancos', 'en tu mundo', 'y somos los obreros', 'en tu viña', 'Declarando la palabra de Dios', 'He aquí que viene', 'Montado en la nubes', 'Brillando como el sol', 'al sonido de la trumpeta', 'Levanta tu voz', 'Es el año de Jubileo', 'Desde El Monte Sion', 'La salvación viene', 'No hay Dios como Jehová']
# ['Como la mujer al pozo', 'Yo estaba buscando', 'Por cosas', 'que no pudieron satisfacer', 'Y luego escuché mi', 'Salvador dice', '"Saca de mi pozo', 'Que nunca se secará"', 'Ten mi copa oh Dios', 'Te la levanto', 'Ven y llena el anhelo', 'de mi ser', 'Pan del cielo, tu sostén', 'me bastara', 'Heme aquí,ven y llena', 'Mi alma hoy', 'Hay millones en este mundo', 'Que anhelan el placer', 'Cosas terrenales permitirse', 'Pero nada coincide', 'El tesoro maravilloso', 'Que encuentro en', 'Jesucristo, mi Señor', 'Ten mi copa oh Dios', 'Te la levanto', 'Ven y llena el anhelo', 'de mi ser', 'Pan del cielo, tu sostén', 'me bastara', 'Heme aquí,ven y llena', 'Mi alma hoy', 'Entonces, mi hermano', 'Si las cosas que este mundo te dio', 'Deja hambres que', 'No desaparecerá', 'Mi bendito Señor', 'Vendrá y te salvará', 'Si te arrodillas', 'Y reza humildemente a él', 'Ten mi copa oh Dios', 'Te la levanto', 'Ven y llena el anhelo', 'de mi ser', 'Pan del cielo, tu sostén', 'me bastara', 'Heme aquí,ven y llena', 'Mi alma hoy']
# ['porque tu, Senor, eres bueno', 'y dispuesto a perdonar', 'porque ere misericordioso', 'con todos los que te invocan', 'Y en mi hora de angustia, O Senor', 'llamare a tu nombre', 'porque me levantaras, Senor', 'y quitaras mi verguenza']
# ['Desde el nacimiento del sol', 'hasta donde se pone', 'Sea alabado el nombre de Jehová', 'Desde el nacimiento del sol', 'hasta donde se pone', 'Sea alabado el nombre de Jehová', 'Jehová es', 'Excelso sobre todas las naciones', 'Y su gloria', 'sobre los cielos', '¿Quién como', 'Jehová nuestro Dios', 'Que se sienta en las alturas', 'Desde el nacimiento del sol', 'hasta donde se pone', 'Sea alabado el nombre de Jehová', 'Desde el nacimiento del sol', 'hasta donde se pone', 'Sea alabado el nombre de Jehová', 'Invocaré a Jehová', 'Quien es digno de ser alabado', 'Y seré salvo', 'De mis enemigos', 'Viva Jehová', 'y bendita sea mi roca', 'Y enaltecido sea el Dios', 'de mi salvación']
# ['Dame aceite en mi lámpara', 'Mantenme ardiendo', 'Dame aceite en mi lámpara', 'Rezo', 'Dame aceite en mi lámpara', 'Mantenme ardiendo', 'Mantenme ardiendo', 'Hasta el descanso del día', 'Canta Hosana  Canta Hosana', 'Canta Hosana  Canta Hosana']
# ['Dios es un Dios bueno', 'si el es', 'Dios es un Dios bueno', 'si el es', 'Dios es un Dios bueno', 'si el es', 'Nuetro Dios es un Dios bueno', 'si el es', 'El me recogio', 'me dio la vuelta', 'El me planto mis pies', 'en terreno mas alto']
# ['Grande y maravilloso', 'Son tus obras maravillosas', 'Oh Dios Todopoderoso', 'Justo y cierto son', 'Todos tus caminos, oh Señor', 'Eres Rey de las edades', '¿Quién no temerá y glorificará', 'Tu nombre, oh Señor?', 'Porque solo tú eres santo', 'Solo tú', 'Todas las naciones vendrán', 'Y te adorarán', 'Porque tu gloria será revelada', 'Aleluya Aleluya', 'Aleluya, Amen', 'Canta Aleluya, Canta Aleluya', 'Canta Aleluya, Canta Aleluya', 'Canta Aleluya, Canta Aleluya', 'Canta Aleluya, Aleluya']
# ['Grande es Dios', 'El es justo y santo', 'por su poder confiamos en su amor', 'Grande es Dios', 'Verdadero y fiel', 'con su misericordia el mostró que el es amor.', 'Grande es Dios', 'Y digno de gloria.', 'Grande es Dios', 'Y digno de alabanzas', 'Grande es Dios', 'levanto mi voz', 'levanto mi voz', 'Grande es Dios', 'Grande es Dios', 'Grande es Dios', 'Y digno de gloria.', 'Grande eres Dios', 'Y digno de alabanzas', 'Grande eres Dios', 'levanto mi voz', 'levanto mi voz', 'Grande es Dios', 'Grande es Dios', 'Grande eres Dios', 'Grande eres Dios']
# ['Él no trajo', ' a nosotros hasta aquí', 'Para llevarnos de vuelta', 'Él nos sacó', 'Para llevarnos a', 'La tierra prometida', 'Él no trajo', 'a nosotros hasta aquí', 'Para llevarnos de vuelta', 'Él nos sacó', 'Para llevarnos a', 'La tierra prometida', 'Aunque hayan gigantes', 'En la tierra', 'No necesitamos tener miedo', 'Él nos sacó', 'Para llevarnos a', 'La tierra prometida', 'Aunque hayan gigantes', 'En la tierra', 'No necesitamos tener miedo', 'Él nos sacó', 'Para llevarnos a', 'La tierra prometida']
# ['Te ha mostrado,hombre', 'Lo que es bueno y', 'Lo que Jehová requiere de ti', 'Te ha mostrado, hombre', 'Lo que es bueno y', 'lo que Jehová requiere de ti', 'hacer justicia', 'Y amar la misericordia', 'Y caminar humildemente', 'con tu Dios', 'hacer justicia', 'Y amar la misericordia', 'Y caminar humildemente', 'con tu Dios']
# ['Dios puede hacer', 'muchisimo en Abundancia', 'Mas que preguntamos o pensamos', 'Dios puede hacer', 'muchisimo en Abundancia', 'Mas que preguntamos o pensamos', 'Por el poder', 'que opera en nosotros', 'Por el poder', 'que opera en nosotros', 'Dios puede hacer', 'muchisimo en Abundancia', 'Mas que preguntamos o pensamos', 'No es por fuerza', 'No es por poder', 'Pero por mi Espiritu', 'Dice el Señor', 'No es por fuerza', 'No es por poder', 'Pero por mi Espiritu', 'Dice el Señor', 'Esta Montana, ha sido removida', 'Esta Montana, ha sido removida', 'Esta Montana, ha sido removida', ' por mi Espiritu dice el Señor']
# ['El es nuestra paz', 'Quien ha derribado todas la paredes', 'El es nuestra paz', 'El es nuestra paz', 'Arroja todas tus preocupaciones sobre el', 'porque El cuida de ti', 'El es nuestra paz', 'El es nuestra paz']
# ['Oye,me clamor,Dios', 'Atiende a mi oracion', 'Desde el fin de la tierra', 'Clamaré a ti', 'cuando mi corazón está abrumado', 'Llévame a la Roca', 'Que es más alta que yo', 'Más alta que yo', 'Porque tú has sido', 'Mi refugio', 'Una torre fuerte', 'Delante del enemigo', 'cuando mi corazón esta abrumado', 'Llévame a la Roca', 'Que es más alta que yo', 'Más alta que yo', 'Yo habitaré', 'En tu tabernáculo', 'Confiare', 'en la sombra de tus alas', 'cuando mi corazón esta abrumado', 'Llévame a la Roca', 'Que es más alta que yo', 'Más alta que yo']
# ['Santidad para el Señor', 'Santidad para el Señor', 'Santidad para el Señor', '(Santidad para el Señor Dios', 'Porque Él es justo', 'Él es fiel', 'Él es soberano sobre todo', 'Porque Él es justo', 'Él es fiel', 'Él es soberano sobre todo']
# ['Santo', 'Santisimo', 'tus caminos son mas altos que los mios', 'Santo', 'Santisimo', 'que tus caminos sean mios', 'Tus caminos son mas altos', 'que las montanas', 'tu amor es mas profundo que el mar', 'tu misericordias fluyen como una fuente', 'han limpiado mi corazon', 'y me han liberado', 'Santo', 'Santisimo', 'tus caminos son mas altos que los mios', 'Santo', 'Santisimo', 'que tus caminos sean mios', 'que tus caminos sean mios']
# ['Santo, Santo Señor, te amo', 'Santo, Santo Cordero de Dios', 'Santo, Santo Señor, te amo', 'Santo, Santo Cordero de Dios', 'El cielo y la tierra', 'se inclinan ante ti', 'El cielo y la tierra', 'Ellos son tuyos', 'El cielo y la tierra', 'se inclinan ante ti', 'El cielo y la tierra', 'Ellos son tuyos', 'He aquí el león de Judá', 'Parado en la puerta', 'Él está vestido con', 'Honor y Majestad', 'Y Él es el rey por siempre', 'El Señor reina', 'Que la gente tiemble', 'Él se sienta entre los querubines', 'El Señor reina', 'Que la gente tiemble', 'Él se sienta entre los querubines', 'Porque el Señor es grande en Sion', 'El Señor es grande en Sion', 'El Señor es grande en Sion']
# ['Hosana en las alturas', 'Hosana en las alturas', 'Señor, levantamos tu nombre', 'Con corazones llenos de alabanza', 'sea exaltado, Señor, mi Dios', 'Hosana en las alturas', 'Gloria, Gloria', 'Gloria al Rey de reyes', 'Gloria, Gloria', 'Gloria al Rey de reyes', 'Señor, levantamos tu nombre', 'Con corazones llenos de alabanza', 'sea exaltado, Señor, mi Dios', 'Hosana en las alturas']
# ['Qué excelente es', 'Tu amorosa bondad', 'O Dios', 'Que excelente es', 'Tu amorosa bondad', 'O Dios', 'Por eso, los hijos de los hombres', 'Pondrán su confianza', 'Bajo la sombra de tu ala', 'Tu misericordia, Señor', 'Esta en los cielos', 'To fidelidad', 'Llega a las nubes', 'Tu justicia es como', 'Una gran montana', 'Tus juicios son muy profundos', 'O Senor']
# ['Oh Señor nuestro Señor', 'que excelente es tu nombre', 'que excelente es tu nombre', 'En toda la tierra', 'Tu gloria llena los cielos', 'Más allá de la estrella más lejana', 'que excelente es tu nombre', 'En toda la tierra', 'Cuando pienso en los cielos', 'La luna y todas las estrellas', 'Me pregunto qué viste en mí', 'Pero me tomaste y me amaste', 'Y me has dado una corona', 'Y ahora alabaré', 'Tu nombre eternamente']
# ['Oh Señor cuán majestuoso', 'Es Tu nombre en toda la tierra', 'Oh Señor cuán majestuoso', 'Es Tu nombre en toda la tierra', 'Oh Señor, alabamos Tu nombre', 'Oh Señor, magnificamos Tu nombre', 'Príncipe de la paz, Poderoso Dios', 'Oh,Dios Todopoderoso']
# ['Tu eres la Roca de mi salvacion', 'Tu eres la fuerza de mi vida', 'tu eres mi esperanza', 'y mi inspracion', 'Senor, a ti llorare', 'Yo Creo en ti', 'creo en ti', 'por tu amor fiel, a mi', 'Has sido mi ayuda', 'en tiempos de necesidad', 'Senor hacia ti me unire']
# ['Te doy todas mis preocupaciones', 'Pongo todas mis cargas', 'A tus pies', 'Y en cualquier momento no lo sé', 'Qué hacer', 'Te daré todas mis preocupaciones', 'Te daré todas mis preocupaciones']
# ['¿A dónde voy', 'Cuando no hay nadie más', 'a quien recurrir?', '¿Con quién hablo', 'Cuando no hay nadie más', 'Que me escuche?', '¿En quién me apoyo', 'cuando no hay', 'una base estable?', 'Voy a la roca', 'Sé que Él es capaz', 'Voy a la roca', 'Voy a la roca de', 'Mi salvacion', 'Voy a la piedra', 'Que los constructores rechazaron', 'Voy a la montaña', 'Y la montaña está a mi lado', 'Cuando todo a mi alrededor es arena que se hunde', 'En Cristo, la roca sólida me parare', 'Cuando necesito un refugio', 'Cuando necesito un amigo', 'Voy a la roca', 'el es mi roca', 'mi espada, mi escudo', 'el es la rueda', 'en el medio de a rueda', 'el es mas bello de los diez mil', 'el es brillante y la estrella de la manana', 'no importa', 'lo que dice la gente', 'voy a servir a mi Senor hoy', 'voy a servir,y servir', 'y servir hasta que venga Jesus', 'solo un poco mas', 'y la trompeta de', 'Dios sonara', 'estoy escuchando', 'solo un poco mas', 'y vamos para gloria', 'estoy esperando', 'mira hacia los cielos', 'nuetra redencion esta cerca', 'estoy mirando', 'mira hacia los cielos', 'hasta que nos encontramos con el en el cielo', 'tu eres mi roca', 'mi espada', 'mi escudo', 'tu eres la rueda en el medio', 'de la rueda', 'eres el mas bello', 'de los diez mil', 'eres brillante', 'y la estrella de la manana', 'no importa', 'lo que dice la gente', 'Voy a servir a mi senor hoy', 'voy a servir, y servir y', 'servir hasta que venga Jeusus']
# ['He decidido', 'Seguir a Cristo', 'He decidido', 'Seguir a Cristo', 'He decidido', 'Sequir a Cristo', 'No vuelvo atrás', 'no vuelvo atrás', 'La cruz delante', 'y el mundo atras', 'La cruz delante', 'y el mundo atras', 'La cruz delante', 'y el mundo atras', 'No vuelvo atrás', 'no vuelvo atrás', 'Si ninguno va conmigo', 'aun sigo', 'Si ninguno va conmigo', 'aun sigo,', 'Si ninguno va conmigo', 'aun sigo a Cristo,', 'No vuelvo atrás', 'no vuelvo atrás', 'Puedes tomar todo este mundo', 'Pero dame a Jesús', 'Puedes tomar todo este mundo', 'Pero dame a Jesús', 'Puedes tomar todo este mundo', 'Pero dame a Jesús', 'No vuelvo atrás', 'no vuelvo atrás']
# ['Escuché la voz', 'De Jesús decir', '"Ven a Mí y descansa', 'Acuéstate, cansado', 'Acuéstate', 'Tu cabeza sobre mi pecho"', 'Y aprende de mí', 'Porque mi yugo es fácil', 'Y mi carga es ligera', 'Y mi carga es ligera']
# ['Me sigo enamorando de él', 'Una y otra y', 'otra y otra vez', 'Me sigo enamorando de él', 'Una y otra y', 'otra y otra vez', 'Se vuelve más y más dulce', 'a medida que pasan los días', 'Oh que amor', 'Entre mi Señor y yo', 'Me sigo enamorando de él', 'Una y otra y', 'otra y otra vez']
# ['He aquí que yo he puesto en Sion', 'Por fundamento una piedra', 'He aquí que yo he puesto en Sion', 'Por fundamento una piedra', 'Piedra probada', 'Piedra angular, preciosa', 'De cimiento estable', 'De cimiento estable', 'Piedra probada', 'Piedra angular, preciosa', 'El que creyere', 'No se apresure', 'Maravilloso consejero', 'Dios Todopoderoso', 'El padre eterno', 'Maravilloso consejero', 'El Príncipe de la Paz', 'El Príncipe de la Paz', 'El Príncipe de la Paz']
# ['Alzaro mis ojos hacia las colinas', 'De donde viene mi ayuda?', 'Mi ayuda viene del Señor', 'Hacedor del cielo y la tierra', 'Hacedor del cielo y la tierra', 'Tu pie nunca se moverá', 'Nunca tropezarás ni te resbalarás', 'El que guarda a Israel', 'No se adormecerá ni dormirá', 'No se adormecerá ni dormirá', 'El Señor te mantendrá fuera de peligro', 'El guarda a tu alma', 'Él te mirará ir y venir', 'Ahora y para siempre', 'Ahora y para siempre', 'Alzaro mis ojos hacia las colinas', 'De donde viene mi ayuda?', 'Mi ayuda viene del Señor', 'Hacedor del cielo y la tierra', 'Hacedor del cielo y la tierra', 'Hacedor del cielo y la tierra']
# ['Amo a Jehová', 'pues ha oído', 'mis súplicas', 'Amo a Jehová', 'pues ha oído mi voz', 'Amo a Jehová', 'Porque ha', 'Inclinado a mí su oído', 'Por tanto, le invocaré', 'En todos mis días', 'Vuelve a tu reposo', 'Oh alma mía', 'Porque Jehová', 'te ha hecho bien', 'Jehová guarda a los sencillos', 'Estaba yo postrado', 'Y me salvó', 'Te amo,Jehová', 'Pues has oído', 'mis súplicas', 'Te amo,Jehová', 'Pues has oído mi voz', 'Te amo,Jehová', 'Porque has inclinado', 'a mí tu oído', 'Por tanto, te invocaré', 'En todos mis días']
# ['Me encanta alabarle', 'Me encanta alabar su nombre', 'Me encanta alabarle', 'Me encanta alabar su nombre', 'Me encanta alabarle', 'Me encanta alabar su nombre', 'Me encanta alabar su nombre santo', 'Él es mi roca', 'Mi roca, mi espada, mi escudo', 'Él es la rueda', 'El rueda en medio de rueda', 'Sé que el nunca', 'Nunca me decepcionará', 'Él es el gozo que encontré', 'Aleluya', 'Aleluya', 'Me encanta alabar su nombre', 'Aleluya', 'Aleluya', 'Me encanta alabar su nombre', 'Aleluya', 'Aleluya', 'Me encanta alabar su nombre', 'Me encanta alabar su nombre santo']
# ['Eres hermoso,mas alla de toda descripcion', 'demasiado maravilloso para palabras', 'demasiado maravilloso para la comprension', 'como nada visto u oido', '¿Quién puede captar tu infinita sabiduría?', '¿Y La profundidad de tu amor?', 'eres hermoso, mas alla de toda descripcion', '¡Majestad entronizado arriba', 'Me quedo,me quedo asombrado de ti,', 'me quedo, me quedo asombrado de ti', 'Dios Santo, a quien se debe toda la alabanza', 'me quedo asombrado de ti']
# ['Fui creado para alabarte', 'Fui creado para glorificar tu nombre', 'En cada circunstancia', 'para buscar la', 'Oportunidad de agradecerte', 'Fui creado para amarte', 'Fui creado para adorar', 'A tus pies', 'Y obedecerte Señor', 'Fui creado para ti', 'Siempre te alabaré', 'Siempre glorificaré tu nombre', 'En cada circunstancia', 'Buscaré la', 'Oportunidad de agradecerte', 'Siempre te amaré', 'Yo siempre adoraré', 'A tus pies', 'Y te obedeceré Señor', 'Fui creado para ti']
# ['Voy a celebrar', 'Cantare a Dios', 'Le cantaré una nueva canción', 'Voy a celebrar', 'Cantare a Dios', 'Le cantaré una nueva canción', 'Lo alabaré', 'Le cantaré una nueva canción', 'Lo alabaré', 'Le cantaré una nueva canción']
# ['Cantaré de las misericordias', 'De Dios perpetuamente', 'Cantaré', 'Cantaré', 'Cantaré de las misericordias', 'De Dios perpetuamente', 'Cantaré', 'De las misericordias de Dios', 'Con mi boca', 'Haré notoria', 'Tu fidelidad', 'Tu fidelidad', 'Con mi boca', 'Haré notoria', 'Tu fidelidad', 'A todas las generaciónes']
# ['Cantaré alabanzas', 'A Dios mi Rey', 'Cantaré alabanzas', 'Cantaré alabanzas', 'Con todo mi ser', 'Cantaré alabanzas', 'Cantaré alabanzas', 'A Dios mi Rey', 'Cantaré alabanzas', 'Cantaré alabanzas', 'Con todo mi ser', 'Cantaré alabanzas', 'Mi meditación de él', 'Será dulce', 'Porque lo amo', 'Daré mi corazón', 'En la celebración', 'Levanto mi voz a lo alto', 'Hare un ruido alegre']
# ['Estaré', 'En la congregación', 'Y yo te exaltaré', 'Estaré', 'En la congregación', 'Y yo te exaltaré', 'Deja que los hijos', 'de tu salvación', 'Levanta sus alabanzas', 'Aleluya Aleluya', 'Estaré', 'En la congregación', 'Y alabaré tu nombre', 'Estaré', 'En la congregación', 'Y alabaré tu nombre', 'Con tu gente de cada nación', 'Gritaré esta alabanza', 'Aleluya Aleluya', 'Aleluya Aleluya', 'Aleluya Aleluya', 'Eres la única inspiración', 'Para mi alabanza Oh Dios', 'Aleluya Aleluya', 'Nos uniremos como congregación', 'Y te exaltaremos', 'Nos uniremos como congregación', 'Y te exaltaremos', 'Vamos a cantar como toda la creación', 'Levanta la canción de nuevo', 'Aleluya Aleluya']
# ['Prefiero tener a Jesús', 'Que plata u oro', 'Prefiero ser suyo', 'que tener riquezas incalculables', 'Prefiero tener a Jesús', 'Que casas o tierras', 'Prefiero ser guiado', 'por sus manos agujereadas', 'Que ser', 'El rey de un vasto dominio', 'Y ser retenido', 'En el dominio del pecado', 'Prefiero tener a Jesús que todos', 'Que este mundo ofrece', 'Él es más dulce que la miel', 'de fuera del panal', 'Él es más justo que el lirio', 'En la floración más rara', 'Él es todo lo que mi espíritu', 'hambriento necesita', 'Prefiero ser suyo', 'Y dejarlo liderar', 'Que ser', 'El rey de un vasto dominio', 'Y ser retenido', 'En el dominio del pecado', 'Prefiero tener a Jesús que todos', 'Que este mundo ofrece', 'Prefiero tener a Jesús', 'que el aplauso de la gente', 'Prefiero ser fiel', 'A su querida causa', 'Prefiero tener a Jesús', 'Que la fama mundial', 'Prefiero ser fiel', 'A su nombre santo', 'Que ser', 'El rey de un vasto dominio', 'Y ser retenido', 'En el dominio del pecado', 'Prefiero tener a Jesús que todos', 'Que este mundo ofrece']
# ['En el nombre de Jesús', 'En el poderoso nombre de Jesús', 'Tenemos la victoria', 'En el nombre de Jesús', 'En el poderoso nombre de Jesús', 'Satanás tendrá que huir', 'En el nombre de Jesús, Jesús', 'Tenemos la victoria!', 'En el nombre de Jesús, Jesús', 'Tenemos la victoria!']
# ['En el comienzo', 'fue la Palabra', 'fue la Palabra', 'Y la Palabra estaba con Dios', 'Y la Palabra estaba con Dios', 'Y la Palabra era Dios', 'Y la Palabra se hizo carne', 'y habitó entre nosotros', 'y habitó entre nosotros', 'Y vimos su gloria', 'como el unigénito del padre', 'Si un hombre me ama', 'Él guardará Mis palabras', 'Y mi padre lo amará', 'Y vendrá a él', 'Si un hombre me ama', 'Él guardará Mis palabras', 'Y mi padre lo amará', 'Y haremos nuestra', 'Morada con él', 'Amarlo', 'Obedece su palabra', 'Y nuestro padre', 'Él te va a querer', 'Tienes que amarlo', 'Obedece su palabra', 'Y el Padre hará', 'su morada contigo']
# ['Está burbujeando', 'Está burbujeando en mi alma', 'Yo canto, Yo grito', 'Porque Jesús me hizo completo', 'Nadie lo entiende', 'Pero no puedo callarme', 'Está burbujeando', 'Está burbujeando', 'Burbuja de día y de noche', 'Lo he encontrado, Lo he encontrado', 'Encontré el camino de la gloria', 'Está burbujeando', 'Está burbujeando en mi alma', 'Lo alabaré, Lo alabaré', 'Lo alabaré todo el día', '¡Gloria Aleluya!', 'Encontré el camino de la gloria', 'Oh, el Espíritu Santo', 'Hará que tus pies bailen', 'El Espíritu Santo te llenará', 'de principio a fin', 'Oh, el Espíritu Santo', 'Hará que tus pies bailen', 'Y hará que tu corazón', 'Baile también']
# ['Tengo un río de vida', 'Fluyendo fuera de mí', 'Hace que el cojo camine', 'Y los ciegos que vean', 'Abre las puertas de la prisión', 'libera los cautivos', 'Tengo un río de vida', 'Fluyendo fuera de mí', 'Burbuja oh pozo', 'dentro de mi alma', 'Burbuja oh pozo', 'eso me llena', 'Burbuja oh pozo', 'Y dame', 'tu vida abundantemente']
# ['Jehová Elohim', 'Adonay, mi rey', 'Jehová Roji', 'Pastor de mi alma', 'Señor en lo alto', 'Jehová, tu eres el cuerno', 'de mi salvación', 'Eres mi roca', 'y mi fortaleza', 'Un escudo alrededor de mí', 'Y mi libertador', 'Jehová eres mi Dios', 'En quien confío', 'Jehová eres mi Dios', 'En quien confío']
# ['Jesus se apodero de mi vida', 'y El no me dejara ir', 'Jesus entro en mi corazon', 'entro en mi alma', 'solia ser tan triste', 'pero ahora soy libre y alegre', 'porque Jesus se apodero de mi vida', 'y El no me dejara ir']
# ['Jesús, nunca olvidaré', 'Lo que has hecho por mí', 'Jesús, nunca olvidaré', 'Cómo me liberaste', 'Jesús, nunca olvidaré', 'Cómo me sacaste', 'Jesús, nunca olvidaré', 'No nunca', '¿Cómo puedo olvidar', 'lo que has hecho por mí?', '¿Cómo puedo olvidar', 'Cómo me liberaste', '¿Cómo puedo olvidar', 'come me secaste', 'como puedo olvidar', 'no, nunca', 'El ha hecho tanto por mi', 'que no puedo decir todo', 'no puedo decir todo', 'no puedo decir todo', 'El ha hecho tanto por mi', 'que no puedo decir todo', 'El ha quitado todos mis pecados']
# ['Conoce, pues', 'que Jehová', 'tu Dios', 'es Dios fiel', 'que guarda el pacto', 'y la misericordia', 'a los que le aman', 'y guardan sus mandamientos', 'Porque el es Dios', 'Aún tu Dios', 'Él es Dios', 'el Dios fiel', 'que guarda el pacto', 'y la misericordia', 'Él es Dios', 'el Dios fiel']
# ['Deja que Dios se levante', 'Deja que sus enemigos se dispersen', 'Deja que Dios se levante', 'Deja que sus enemigos se dispersen lejos', 'Muy lejos', 'Deja que los justos se alegren', 'Deja que se regocijen ante Dios', 'Deja que los justos se alegren', 'Que se regocijen mucho']
# ['Levántese Dios', 'Levántese Dios', 'Levántese Dios', 'Levántese Dios', 'Sean esparcidos sus enemigos', 'Mas los justos se alegrarán', 'Se saltarán de alegría delante de Dios', 'Dios ha triunfado gloriosamente', 'No temas porque yo estoy contigo', 'No temas porque yo estoy contigo', 'No temas porque yo estoy contigo', 'Dice Jehová', 'Yo te redimí', 'Te puse nombre', 'Mío eres tú', 'Cuando pases por las aguas', 'Yo estaré contigo', 'Y por el fuego', 'No te ahogarás', 'No te quemarás', 'Porque estoy contigo']
# ['Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Alabadle, cielo de los cielos.', 'Alabadle, sol y luna', 'Alabadle, todos sus ángeles', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Vamos a alabar el nombre del Señor', 'Alabadle, colinas y montañas', 'Alabadle, lagos y rios', 'Alabadle, hijos de Jacob', 'Alabadle, semilla de Israel']
# ['Levantalo', 'Levantalo', 'Levanta el nombre de Jesús más alto', 'Levantalo', '¡Levanta Su estandarte al cielo!', 'Él dijo: "Si me levantan,', 'Atraeré a todos los hombres hacia mí "', 'Levantalo', 'Toda la gente, levantanlo', 'Alabad al Señor', 'Alabad al Señor', 'Alabad su justicia para siempre', 'Alabad al Señor', 'Levanta tus voces al cielo', 'Él dijo que si no alabamos Su nombre', '¡Entonces las rocas y las piedras gritarán!', 'Alabad al Señor', 'Toda la gente, ¡alabad al Señor!', 'Muestra su amor', 'Muestra su amor', 'Muestra su amor el uno al otro', 'Muestra su amor', 'Deja que tu vela siempre brille', 'Él dijo que por el amor que mostramos', 'Ellos sabrán que somos Sus discípulos.', 'Muestra su amor', 'Toda la gente, ¡demuestren Su amor!']
# ['Levanta tus voces', 'Canta Aleluya', 'El Mesías prometido vendrá', 'Trayendo alegría al mundo', 'Esperanza para las naciones', 'Y paz para todas', 'El celo del Señor', 'Lo realizará', 'Y haz que todo suceda', 'El celo del Señor', 'Lo realizará', 'El Mesías vendrá por fin']
# ['Tu nombre levantare', 'Me encanta cantar tus alabanzas', 'Estoy alegre que estas en mi vida', 'estoy alegre que vinistes a salvarme', 'viniste del cielo para la tierra', 'para mostrar el camino', 'De la tierra a la Cruz', 'mi deuda pagaste', 'De la Cruz a la tumba', 'De la tumba al cielo', 'Tu Nombre yo levantare']
# ['Señor Jesucristo', 'Señor Jesucristo', 'El unigénito', 'Hijo del padre', 'Señor Jesucristo', 'Señor Jesucristo', 'El unigénito', 'Hijo del padre', 'Eres el Rey de reyes', 'Señor de señores', 'El Anciano de los Días', 'Rey de Reyes', 'Señor de señores', 'La Vida, la Verdad', 'Y la Via']
# ['Tú eres el Cristo', 'El Hijo del Dios viviente', 'Jesús, Señor de todos', 'Rey justo', 'Para ti yo canto', 'Y en tu nombre llamo', 'Santo, santo', 'Tú eres el Hijo de Dios', 'Tú eres el Hijo de Dios', 'Santo, santo', 'Tú eres el Hijo de Dios', 'Tú eres el Hijo de Dios', 'Señor Jesucristo', 'Tú eres el Hijo de Dios', 'Tú eres el Hijo de Dios', 'Señor Jesucristo', 'Tú eres el Hijo de Dios', 'Tú eres el Hijo de Dios']
# ['Señor del amor', 'Has ganado mi corazón', 'Tu amor perdurará para siempre', 'Señor del amor', 'Has ganado mi corazón', 'Tu amor perdurará para siempre', 'Cada momento, cada hora', 'Te quedas mi fiel torre', 'En tus brazos, descanso seguro']
# ['Señor, deja que tu luz', 'Luz de tu cara', 'brilla sobre nosotros', 'Señor, deja que tu luz', 'Luz de tu cara', 'brilla sobre nosotros', 'Para que podamos ser salvados', 'Que podemos tener luz', 'Para encontrar nuestro camino', 'En la noche más oscura', 'Deja que tu luz brille sobre nosotros', 'Señor deja que tu gracia', 'Gracia de tu mano', 'Caiga sobre nosotros', 'Señor deja que tu gracia', 'Gracia de tu mano', 'Caiga sobre nosotros', 'Para que podamos ser salvados', 'Que podemos tener luz', 'Para encontrar nuestro camino', 'En la noche más oscura', 'Deja que tu gracia caiga sobre nosotros', 'Señor deja que tu amor', 'Amor sin fin', 'Ven a nosotros', 'Señor deja que tu amor', 'Amor sin fin', 'Ven a nosotros', 'Para que podamos ser salvados', 'Que podemos tener luz', 'Para encontrar nuestro camino', 'En la noche más oscura', 'Deja que tu amor venga a nosotros', 'Deja que tu luz brille sobre nosotros']
# ['Majestad, adoramos su majestad', 'Para Jesús, toda la gloria', 'Honor y alabanza', 'Majestad, Rey de Autoridad', 'Ven de tu trono', 'A los tuyos, Te cantaremos', 'Exalta, levantate en lo alto', 'El nombre de Jesús', 'Magnifica, glorifica', 'Jesús Cristo el Rey', 'Majestad, adoramos su majestad', 'Jesús que murió, ahora es glorificado', 'El Rey de los reyes']
# ['Mencionen que Su nombre', 'Es exaltado.', 'Mencionen que Su nombre', 'Es exaltado.', 'Porque el ha hecho cosas magníficas', ' esto saben por toda la tierra.', 'griten y canten, habitantes', 'De Sion', 'griten y canten, habitantes', 'De Sion', 'Porque grande es el Santo', 'Grande es el Santo en de Israel']
# ['Maranatha Jesús', 'Maranatha Cristo nuestro Rey', 'Maranatha Jesús', 'nosotros, Tu iglesia clamamos a Ti', 'nosotros,Tu novia te anhelamos', 'Anhelamos tu aparición', 'y La trompeta de Dios', 'Anhelamos tu aparición', 'y Por el grito del arcángel', 'y Por el grito del arcángel', 'Maranatha Jesús', 'Maranatha Cristo nuestro Rey', 'Maranatha Jesús', 'nosotros, tu iglesia clamamos a Ti', 'nosotros, tu novia te anhelamos', 'Anhelamos tu aparición', 'y Que los muertos en ti se levanten', 'Anhelamos tu aparición', 'y el rapto de los vivos', 'y el rapto de los vivos']
# ['Que todos los que viven crean en Ti', 'Y santifiquen tu nombre en verdad', 'Que todos los que viven crean en Ti', 'Y santifiquen tu nombre en verdad', 'Porque tú eres nuestra salvación', 'Yeshua, Jesús eres el único', 'Porque tú eres nuestra salvación', 'Yeshua, Jesús eres el único', 'Tú eres el Señor, Sí, eres el Señor', 'Tú eres el Señor, Sí, eres el Señor']
# ['Que el Senor Dios te escuche', 'En el dia de problemas', 'El nombre del Dios', 'de Jacob', 'Te ponga en el alto', 'Y que te envia ayuda', 'Del santuario', 'Y te fortalece', 'Fuera de Sion', 'que te Fortalece', 'Nos regocijaremos', 'En el Dios de nuestra salvacion', 'Vamos a poner', 'Nuestros carteles en alto', 'Algunos confian en carros', 'Y otros in caballos', 'Pero recordaremos', 'El nombre de nuestro Dios']
en', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen', 'amen']
# ['Te doy la gloria', 'Te doy la honra', 'Te doy mi vida', 'Te alabaré', 'Te doy la gloria', 'Te doy la honra', 'Te doy mi vida', 'Te alabaré', 'Eres mi dulce Salvador', 'Y mi bendito Redentor', 'Por mi moriste, me diste vida', 'Te doy mi vida, te alabaré']
# ['Hay un rio de alegria', 'Que se derrama de las venas de Emmanuel', 'Este pecador fue hundido', 'Debajo de la inundacion y se salvo', 'Desde entonces camino perdonado', 'Toda mi culpa fue borrada', 'Las cadenas del pasado', 'Estan rotas por fin', 'Me salvé', '¡Oh, me salve!', 'Sin la misericordia de Jesús, estoy desecho', 'Sin la bondad del Señor, estoy deshecho', 'Estoy restaurado y hecho bien', 'Se apodero de mi vida', 'Tengo a Jesus', '¿Como puedo querer más?', 'He recibido tu bondad amorosa', 'He probado Tu bondad y gracia', 'Estaba tan perdido', 'hasta que me cai en la cruz', 'Y fui salvo', '¡Oh, me salvé!', 'Sin la misericordia de Jesús, estoy deshecho', 'Sin la bondad del Señor, estoy deshecho', 'Estoy restaurado y hecho bien', 'Se apodero de mi vida', 'Tengo a Jesús', '¿Como puedo querer más?', 'El amor de Dios me dio su perdón', 'El amor de Dios no me dejará permanecer igual', 'El amor de Dios me lleva más alto', 'Su verdad es mayor', 'Es por eso que me salve', 'Sin la misericordia de Jesús, estoy deshecho', 'Sin la bondad del Señor, estoy deshecho', 'Estoy restaurado y hecho bien', 'Se apodero de mi vida', 'Tengo a Jesús', '¿Como puedo querer más?', 'Sin la misericordia de Jesús, estoy deshecho', 'Sin la bondad del Señor, estoy deshecho', 'Estoy restaurado y hecho bien', 'Se apodero de mi vida', 'Tengo a Jesús', '¿Como puedo querer más?', 'Tengo a Jesús', '¿Como puedo querer más?', 'Tengo a Jesús', '¿Como puedo querer más?']
# ['I just want to bless you', 'I want to give you glory', 'I want to give all honor to you Lord', 'At Your feet I bow down', 'I exalt Your name', "I'll give to You my heart of worship Lord", 'Worshipping Your name', 'Worshipping Your name', 'In Your presence I will stay', 'And be there all my days', 'Worshipping Your name', 'Worshipping Your name', 'In Your presence I will stay', 'And be there all my days', 'Worshipping Your name', 'The high and exalted', 'The Lion and the Lamb', 'No one is like You', 'Holy I AM']
# ['We do', 'We do', 'We do', 'We do', 'It is', 'It is', 'It is', 'It is', 'He does', 'He does', 'He does', 'He does']
# ['repeat']
# ['X3']
# ['You overcame', 'You overcame']
#    id  song  instrument                                              words  \
# 0   1     1           8  Faithful One\r\nSo unchanging\r\nAgeless One\r...
# 1   2     2           8  Ah, Lord God\r\n(!Oh Señor Jehová!) \r\nThou h...
# 2   3     3           8  Jesus is my\r\nLord and savior,\r\nSent here t...
# 3   5     5           8  All honor,\r\nAll glory,\r\nAll power to You.\...
# 4   7     7           8  All the way to Calvary \r\n(Todo el camino al ...
#
#                                              english  \
# 0  Faithful One\r\nSo unchanging\r\nAgeless One\r...
# 1  Ah, Lord God\r\n \r\nThou hast made the heaven...
# 2  Jesus is my\r\nLord and savior,\r\nSent here t...
# 3  All honor,\r\nAll glory,\r\nAll power to You.\...
# 4  All the way to Calvary \r\n\r\nHe went for me,...
#
#                                              spanish   mime_type
# 0                                               None  text/plain
# 1  !Oh Señor Jehová! He aquí que tú hiciste el ci...  text/plain
# 2                                               None  text/plain
# 3                                               None  text/plain
# 4  Todo el camino al Calvario Él fue por mí Él fu...  text/plain

# %% [markdown]
# ## Define access methods to Destination MongoDB
#
#
# * _connect
# * read_mongo - reads from a mongo database collection
# * write_mongo - writes a Dataframe into a mongo database collection

# %%
import pandas as pd
from pymongo import MongoClient


def _connect_mongo(host, port, username, password, db):
    """ A util for making a connection to mongo """

    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, db)
        conn = MongoClient(mongo_uri)
    else:
        conn = MongoClient(host, port)

    return conn[db]


def read_mongo(db, collection, query={}, host='localhost', port=27017, username=None, password=None, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = _connect_mongo(host=host, port=port, username=username, password=password, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query)
    
    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    # Delete the _id
    if no_id:
        del df['_id']

    return df

def write_mongo(db, collection, df, host='localhost', port=27017, username=None, password=None, no_id=True):
    """Write a Dataframe to a Mongo Database"""
    # Connect to MongoDB
    db = _connect_mongo(host=host, port=port, username=username, password=password, db=db)
    
    # Remove previous data
    db[collection].drop()

    # Write the data
    #df.reset_index(inplace=True)
    data = df.to_dict(orient='records')  # Here's our added param..
    db[collection].insert_many(data)

# %% [markdown]
# ## Write Data
#
# * songs into songs collection
# * scores into the scores collection

# %%
write_mongo('music', 'songs', songs)
write_mongo('music', 'scores', scores)

# %%
# Test the songs collection result
sngs = read_mongo('music', 'songs')
sngs.head()
# Out:
#    id  tempo_cd_id                     arrangement   tag  \
# 0   1            1  Faithful one, so unchanging...  Main
# 1   2            4                            None  Main
# 2   3            3     Jesus is my Lord and Savior  Main
# 3   5            2                            None  Main
# 4   7            4                            None  Main
#
#                          title start_key aux_key               begin_english  \
# 0                  Ageless One         C    None  Faithful One So unchanging
# 1  Ah Lord God /In Him We Live         C    None           Ah, Lord God Thou
# 2     You're Alive Forevermore        Dm    None            Jesus is my Lord
# 3         All Honor, All Glory        Dm    None       All honor, All glory,
# 4       All The Way To Calvary      Eb/F    None              All the way to
#
#        begin_spanish  note
# 0               None  None
# 1  !Oh Señor Jehová!  None
# 2               None  None
# 3               None  None
# 4  Todo el camino al  None

# %%
# Test the scores collection result
scr = read_mongo('music', 'scores')
scr.head()
# Out:
#    id  song  instrument                                              words  \
# 0   1     1           8  Faithful One\r\nSo unchanging\r\nAgeless One\r...
# 1   2     2           8  Ah, Lord God\r\n(!Oh Señor Jehová!) \r\nThou h...
# 2   3     3           8  Jesus is my\r\nLord and savior,\r\nSent here t...
# 3   5     5           8  All honor,\r\nAll glory,\r\nAll power to You.\...
# 4   7     7           8  All the way to Calvary \r\n(Todo el camino al ...
#
#                                              english  \
# 0  Faithful One\r\nSo unchanging\r\nAgeless One\r...
# 1  Ah, Lord God\r\n \r\nThou hast made the heaven...
# 2  Jesus is my\r\nLord and savior,\r\nSent here t...
# 3  All honor,\r\nAll glory,\r\nAll power to You.\...
# 4  All the way to Calvary \r\n\r\nHe went for me,...
#
#                                              spanish   mime_type
# 0                                               None  text/plain
# 1  !Oh Señor Jehová! He aquí que tú hiciste el ci...  text/plain
# 2                                               None  text/plain
# 3                                               None  text/plain
# 4  Todo el camino al Calvario Él fue por mí Él fu...  text/plain
